# %%
# Data_advertising

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# Load the data
data=pd.read_csv("Data_Advertising.csv")
# split the dataset
x=np.array(data.sales).reshape(-1,1)
y=np.array(data.TV).reshape(-1,1)

# Load the model
linear_regression_model=linear_model.LinearRegression()

# Train the model:fit
linear_regression_model.fit(x,y)

# Test the model
xtest=np.array([3.0,1.0,9.0,5.2]).reshape(-1,1)
xtest=x
ytest_result=linear_regression_model.predict(xtest)
plt.scatter(x,y,color="red")
plt.scatter(x,ytest_result,color="blue")
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.show()

# %%
# Radio vs sale

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# Load the data
data=pd.read_csv("Data_Advertising.csv")
# split the dataset
x=np.array(data.sales).reshape(-1,1)
y=np.array(data.radio).reshape(-1,1)

# Load the model
linear_regression_model=linear_model.LinearRegression()

# Train the model:fit
linear_regression_model.fit(x,y)

# Test the model
xtest=np.array([3.0,1.0,9.0,5.2]).reshape(-1,1)
xtest=x
ytest_result=linear_regression_model.predict(xtest)
plt.scatter(x,y,color="red")
plt.scatter(x,ytest_result,color="blue")
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.show()

# %%
# Newspaper vs sales

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# Load the data
data=pd.read_csv("Data_Advertising.csv")
# split the dataset
x=np.array(data.newspaper).reshape(-1,1)
y=np.array(data.TV).reshape(-1,1)

# Load the model
linear_regression_model=linear_model.LinearRegression()

# Train the model:fit
linear_regression_model.fit(x,y)

# Test the model
xtest=np.array([3.0,1.0,9.0,5.2]).reshape(-1,1)
xtest=x
ytest_result=linear_regression_model.predict(xtest)
plt.scatter(x,y,color="red")
plt.scatter(x,ytest_result,color="blue")
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.show()

# %%
# Insuarence 

import pandas as pd
import numpy as np
from sklearn import linear_model,model_selection,preprocessing
import matplotlib.pyplot as plt
                    
# Load the data
data=pd.read_csv("insurance.csv")

# identify x and y
label_encoder=preprocessing.LabelEncoder()
x=np.array(label_encoder.fit_transform(data.sex)).reshape(-1,1)
y=np.array(data.expenses).reshape(-1,1)

# split the datast in training and testing
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.3)

# Load the model
lr=linear_model.LinearRegression()
lr.fit(xtrain,ytrain)

# test the model
ytest_predicted=lr.predict(xtest)

# print(ytest)
# print(ytest_predicted)
# visualization
plt.scatter(xtrain,ytrain,color="red")
plt.scatter(xtest,ytest,color="blue")
plt.show()

# %%
# Weather

import pandas as pd
import numpy as np
from sklearn import linear_model,model_selection,preprocessing
import matplotlib.pyplot as plt

                     
# Load the data
data=pd.read_csv("Weather.csv")

# identify x and y
label_encoder=preprocessing.LabelEncoder()
x=np.array(label_encoder.fit_transform(data.MaxTemp)).reshape(-1,1)
y=np.array(data.YR).reshape(-1,1)

# split the datast in training and testing
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.3)

# Load the model
lr=linear_model.LinearRegression()
lr.fit(xtrain,ytrain)

# test the model
ytest_predicted=lr.predict(xtest)

# print(ytest)
# print(ytest_predicted)
# visualization
plt.scatter(xtrain,ytrain,color="red")
plt.scatter(xtest,ytest,color="blue")
plt.show()
# Out:
# C:\Users\91757\AppData\Local\Temp\ipykernel_16460\1426500429.py:10: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("Weather.csv")
